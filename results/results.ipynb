# %%
import pandas as pd

# %%
hy1 = pd.read_csv("../MEME_FIMO/Re__project_-_proteins_w__promoter_consensus_seq/fimo_hydra1.tsv", delimiter='\t')

# %%
hy1
# Out:
#                                                motif_id motif_alt_id  \
# 0                                              MA0150.1       NFE2L2
# 1                                              MA0150.1       NFE2L2
# 2                                              MA0150.1       NFE2L2
# 3                                              MA0150.1       NFE2L2
# 4                                              MA0150.1       NFE2L2
# 5                                              MA0150.1       NFE2L2
# 6                                              MA0150.1       NFE2L2
# 7                                              MA0150.1       NFE2L2
# 8                                              MA0150.1       NFE2L2
# 9                                              MA0150.1       NFE2L2
# 10                                             MA0150.1       NFE2L2
# 11                                             MA0150.1       NFE2L2
# 12                                             MA0150.1       NFE2L2
# ...

# %%
#hy1.columns[2]

# %%
hy1 = hy1["sequence_name"][:-3]

# %%
len(hy1)
# Out:
# 3513

# %%
len(hy1.unique())
# Out:
# 3242

# %%
hy1 = hy1.drop_duplicates()

# %%
hy2 = pd.read_csv("../MEME_FIMO/Re__project_-_proteins_w__promoter_consensus_seq/fimo_hydra2.tsv", delimiter='\t')
hy2 = hy2["sequence_name"][:-3]
print(len(hy2))
print(len(hy2.unique()))
hy2 = hy2.drop_duplicates()
print(len(hy2))
# Out:
# 3393
# 3091
# 3091

# %%
hy3 = pd.read_csv("../MEME_FIMO/Re__project_-_proteins_w__promoter_consensus_seq/fimo_hydra3.tsv", delimiter='\t')
hy3 = hy3["sequence_name"][:-3]
print(len(hy3))
print(len(hy3.unique()))
hy3 = hy3.drop_duplicates()
print(len(hy3))
# Out:
# 4970
# 4540
# 4540

# %%
hy_lo = set(hy1) | set(hy2) | set(hy3)
hy_hi = set(hy1) & set(hy2) & set(hy3)

# %%
print(len(hy_lo))
print(len(hy_hi))
# Out:
# 7207
# 1046

# %%
f = open("hydra_low.txt", "w")
f.write('\n'.join(hy_lo))
# Out:
# 138438

# %%
f = open("hydra_high.txt", "w")
f.write('\n'.join(hy_hi))
# Out:
# 20078

# %%
dm1 = pd.read_csv("../MEME_FIMO/Re__project_-_proteins_w__promoter_consensus_seq/fimo_dmel1.tsv", delimiter='\t')
dm1 = dm1["sequence_name"][:-3]
print(len(dm1))
dm1 = dm1.drop_duplicates()
print(len(dm1))
# Out:
# 4355
# 4023

# %%
dm2 = pd.read_csv("../MEME_FIMO/Re__project_-_proteins_w__promoter_consensus_seq/fimo_dmel2.tsv", delimiter='\t')
dm2 = dm2["sequence_name"][:-3]
print(len(dm2))
dm2 = dm2.drop_duplicates()
print(len(dm2))
# Out:
# 4153
# 3837

# %%
dm3 = pd.read_csv("../MEME_FIMO/Re__project_-_proteins_w__promoter_consensus_seq/fimo_dmel3.tsv", delimiter='\t')
dm3 = dm3["sequence_name"][:-3]
print(len(dm3))
dm3 = dm3.drop_duplicates()
print(len(dm3))
# Out:
# 5682
# 5103

# %%
dm_lo = set(dm1) | set(dm2) | set(dm3)
dm_hi = set(dm1) & set(dm2) & set(dm3)
print(len(dm_lo))
print(len(dm_hi))
# Out:
# 8700
# 1088

# %%
f = open("dmel_low.txt", "w")
f.write('\n'.join(dm_lo))
# Out:
# 104399

# %%
f = open("dmel_high.txt", "w")
f.write('\n'.join(dm_hi))
# Out:
# 13055

# %%
hs1 = pd.read_csv("../MEME_FIMO/Re__project_-_proteins_w__promoter_consensus_seq/fimo_hsap1.tsv", delimiter='\t')
hs1 = hs1["sequence_name"][:-3]
print(len(hs1))
hs1 = hs1.drop_duplicates()
print(len(hs1))
# Out:
# 10658
# 9464

# %%
hs2 = pd.read_csv("../MEME_FIMO/Re__project_-_proteins_w__promoter_consensus_seq/fimo_hsap2.tsv", delimiter='\t')
hs2 = hs2["sequence_name"][:-3]
print(len(hs2))
hs2 = hs2.drop_duplicates()
print(len(hs2))
# Out:
# 11293
# 9868

# %%
hs3 = pd.read_csv("../MEME_FIMO/Re__project_-_proteins_w__promoter_consensus_seq/fimo_hsap3.tsv", delimiter='\t')
hs3 = hs3["sequence_name"][:-3]
print(len(hs3))
hs3 = hs3.drop_duplicates()
print(len(hs3))
# Out:
# 6960
# 6348

# %%
hs_lo = set(hs1) | set(hs2) | set(hs3)
hs_hi = set(hs1) & set(hs2) & set(hs3)
print(len(hs_lo))
print(len(hs_hi))
# Out:
# 16073
# 2083

# %%
f = open("hsap_low.txt", "w")
f.write('\n'.join(hs_lo))
# Out:
# 305386

# %%
f = open("hsap_high.txt", "w")
f.write('\n'.join(hs_hi))
# Out:
# 39576

# %%
sco = eval(open("SCO_OG.txt").read())

# %%
len(sco)
# Out:
# 1074

# %%
list(sco.values())[0]
# Out:
# ' FBpp0070078 GENSCAN00000043295 Sc4wPfr_305.g4608.t1'

# %%
list(hy_lo)[1:10] in sco.values()
# Out:
# False

# %%
"Sc4wPfr_50.g22247" in sco['OG0004309']
# Out:
# True

# %%
hy_hi_OG = []
[hy_hi_OG.append(i) for i in sco if any(j in sco[i] for j in hy_hi)]
print(len(hy_hi_OG))
print('\n'.join(hy_hi_OG))
# Out:
# 25
# OG0004308
# OG0004320
# OG0004355
# OG0004361
# OG0004430
# OG0004480
# OG0004586
# OG0004593
# OG0004631
# OG0004642
# OG0004829
# OG0004845
# OG0004866
# OG0004868
# OG0004891
# OG0005004
# OG0005035
# OG0005042
# OG0005133
# OG0005158
# OG0005431
# OG0005483
# OG0005489
# OG0005590
# OG0005621

# %%
dm_hi_OG = []
[dm_hi_OG.append(i) for i in sco if any(j in sco[i] for j in dm_hi)]
print(len(dm_hi_OG))
print('\n'.join(dm_hi_OG))
# Out:
# 29
# OG0004289
# OG0004328
# OG0004331
# OG0004494
# OG0004527
# OG0004530
# OG0004547
# OG0004552
# OG0004585
# OG0004593
# OG0004692
# OG0004703
# OG0004733
# OG0004760
# OG0004764
# OG0004776
# OG0004962
# OG0005059
# OG0005142
# OG0005158
# OG0005171
# OG0005184
# OG0005349
# OG0005394
# OG0005430
# OG0005519
# OG0005526
# OG0005597
# OG0005654

# %%
hs_hi_OG = []
[hs_hi_OG.append(i) for i in sco if any(j in sco[i] for j in hs_hi)]
print(len(hs_hi_OG))
print('\n'.join(hs_hi_OG))
# Out:
# 44
# OG0004260
# OG0004299
# OG0004339
# OG0004387
# OG0004394
# OG0004415
# OG0004431
# OG0004465
# OG0004495
# OG0004520
# OG0004575
# OG0004580
# OG0004591
# OG0004640
# OG0004657
# OG0004678
# OG0004709
# OG0004768
# OG0004913
# OG0004927
# OG0004936
# OG0004946
# OG0004955
# OG0005012
# OG0005013
# OG0004517
# OG0004519
# OG0004522
# OG0004527
# OG0004530
# OG0004533
# OG0004540
# OG0004544
# OG0004547
# OG0004552
# OG0004558
# OG0004560
# OG0004561
# OG0004567
# OG0004570
# OG0004572
# OG0004578
# ...

# %%
f = open("dm_lo_sco.txt", "w")
f.write('\n'.join(dm_lo_OG))
# Out:
# 2999

# %%
hs_lo_OG = []set
[hs_lo_OG.append(i) for i in sco if any(j in sco[i] for j in hs_lo)]
print(len(hs_lo_OG))
print('\n'.join(hs_lo_OG))
# Out:
# 334
# OG0004252
# OG0004255
# OG0004258
# OG0004260
# OG0004268
# OG0004271
# OG0004273
# OG0004274
# OG0004291
# OG0004299
# OG0004303
# OG0004306
# OG0004308
# OG0004310
# OG0004312
# OG0004315
# OG0004317
# OG0004318
# OG0004319
# OG0004320
# OG0004328
# OG0004333
# OG0004338
# OG0004339
# OG0004342
# OG0004346
# OG0004349
# OG0004350
# OG0004354
# OG0004362
# OG0004368
# OG0004374
# OG0004378
# OG0004381
# OG0004387
# OG0004392
# OG0004394
# OG0004401
# OG0004410
# OG0004415
# OG0004425
# OG0004428
# OG0004431
# OG0004433
# OG0004439
# OG0004451
# OG0004456
# OG0004465
# OG0004469
# OG0004476
# OG0004477
# OG0004480
# OG0004485
# OG0004487
# OG0004494
# OG0004495
# OG0004497
# OG0004514
# OG0004515
# OG0004518
# OG0004520
# OG0004524
# OG0004527
# OG0004533
# OG0004535
# OG0004539
# OG0004544
# OG0004548
# OG0004551
# OG0004552
# OG0004556
# OG0004557
# OG0004559
# OG0004563
# OG0004571
# OG0004575
# OG0004580
# OG0004589
# OG0004591
# OG0004597
# OG0004599
# OG0004600
# ...

# %%
f = open("hs_lo_sco.txt", "w")
f.write('\n'.join(hs_lo_OG))
# Out:
# 3339

# %%
ortho = eval(open("../results/OG.txt",'r').read())

# %%
len(ortho)
# Out:
# 4494

# %%
hy_hi
# Out:
# {'Sc4wPfr_789.g22440',
#  'Sc4wPfr_50.g22215',
#  'Sc4wPfr_1630.1.g20713',
#  'Sc4wPfr_1177.g14231',
#  'Sc4wPfr_347.g19312',
#  'Sc4wPfr_761.g1896',
#  'Sc4wPfr_170.g7327',
#  'Sc4wPfr_175.1.g31533',
#  'Sc4wPfr_440.g6795',
#  'Sc4wPfr_343.1.g25981',
#  'Sc4wPfr_977.g21613',
#  'Sc4wPfr_390.g5645',
#  'Sc4wPfr_2241.g17576',
#  'Sc4wPfr_113.1.g28337',
#  'Sc4wPfr_727.g7584',
#  'Sc4wPfr_720.g12292',
#  'Sc4wPfr_854.g18438',
#  'Sc4wPfr_4858.g21469',
#  'Sc4wPfr_66.g19038',
#  'Sc4wPfr_1100.g15597',
#  'Sc4wPfr_2050.g26577',
#  'Sc4wPfr_1251.g5850',
#  'Sc4wPfr_50.g22237',
#  'Sc4wPfr_586.g22358',
#  'Sc4wPfr_957.g32698',
